# %% [markdown]
# # **Waste Material Segregation for Improving Waste Management**

# %% [markdown]
# ## **Objective**
#
# The objective of this project is to implement an effective waste material segregation system using convolutional neural networks (CNNs) that categorises waste into distinct groups. This process enhances recycling efficiency, minimises environmental pollution, and promotes sustainable waste management practices.
#
# The key goals are:
#
# * Accurately classify waste materials into categories like cardboard, glass, paper, and plastic.
# * Improve waste segregation efficiency to support recycling and reduce landfill waste.
# * Understand the properties of different waste materials to optimise sorting methods for sustainability.

# %% [markdown]
# ## **Data Understanding**
#
# The Dataset consists of images of some common waste materials.
#
# 1. Food Waste
# 2. Metal
# 3. Paper
# 4. Plastic
# 5. Other
# 6. Cardboard
# 7. Glass

# %% [markdown]
# **Data Description**
#
# * The dataset consists of multiple folders, each representing a specific class, such as `Cardboard`, `Food_Waste`, and `Metal`.
# * Within each folder, there are images of objects that belong to that category.
# * However, these items are not further subcategorised. <br> For instance, the `Food_Waste` folder may contain images of items like coffee grounds, teabags, and fruit peels, without explicitly stating that they are actually coffee grounds or teabags.

# %% [markdown]
# ## **1. Load the data**

# %% [markdown]
# **Import Necessary Libraries**

# %% [markdown]
# Load and unzip the dataset zip file.

# %%
# Recommended versions:python3.10 --version

# numpy version: 1.26.4
# pandas version: 2.2.2
# seaborn version: 0.13.2
# matplotlib version: 3.10.0
# PIL version: 11.1.0
# tensorflow version: 2.18.0
# keras version: 3.8.0
# sklearn version: 1.6.1

# %%
# Note: TensorFlow cannot be installed in the latest version of Python, only in Python 3.10.
# Make sure to install Python 3.10, create a new environment, and select the 3.10 kernel for this project.
#
# To install required packages, run the following in your terminal or uncomment the line below:
# !pip install numpy pandas seaborn matplotlib Pillow tensorflow keras scikit-learn

# %%
# Import essential libraries
import tensorflow as tf
print(tf.__version__)   # TensorFlow version

import keras
print(keras.__version__)  # Keras version
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 2
#       1 # Import essential libraries
# ----> 2 import tensorflow as tf
#       3 print(tf.__version__)   # TensorFlow version
#       5 import keras
#
# File c:\Users\I065659\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\__init__.py:469
#     467     importlib.import_module("tf_keras.src.optimizers")
#     468   else:
# --> 469     importlib.import_module("keras.src.optimizers")
#     470 except (ImportError, AttributeError):
#     471   pass
#
# File c:\Users\I065659\AppData\Local\Programs\Python\Python310\lib\importlib\__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File c:\Users\I065659\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\__init__.py:7
#       1 """DO NOT EDIT.
#       2
#       3 This file was autogenerated. Do not edit it by hand,
#       4 since your modifications would be overwritten.
#       5 """
# ----> 7 from keras import _tf_keras as _tf_keras
#       8 from keras import activations as activations
#       9 from keras import applications as applications
#
# File c:\Users\I065659\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\_tf_keras\__init__.py:1
# ----> 1 from keras._tf_keras import keras
#
# File c:\Users\I065659\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\_tf_keras\keras\__init__.py:29
#      27 from keras import utils as utils
#      28 from keras import visualization as visualization
# ---> 29 from keras import wrappers as wrappers
#      30 from keras._tf_keras.keras import backend as backend
#      31 from keras._tf_keras.keras import layers as layers
#
# File c:\Users\I065659\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\wrappers\__init__.py:7
#       1 """DO NOT EDIT.
#       2
#       3 This file was autogenerated. Do not edit it by hand,
#       4 since your modifications would be overwritten.
#       5 """
# ----> 7 from keras.src.wrappers.sklearn_wrapper import (
#       8     SKLearnClassifier as SKLearnClassifier,
#       9 )
#      10 from keras.src.wrappers.sklearn_wrapper import (
#      11     SKLearnRegressor as SKLearnRegressor,
#      12 )
#      13 from keras.src.wrappers.sklearn_wrapper import (
#      14     SKLearnTransformer as SKLearnTransformer,
#      15 )
#
# File c:\Users\I065659\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\wrappers\__init__.py:1
# ----> 1 from keras.src.wrappers.sklearn_wrapper import SKLearnClassifier
#       2 from keras.src.wrappers.sklearn_wrapper import SKLearnRegressor
#       3 from keras.src.wrappers.sklearn_wrapper import SKLearnTransformer
#
# File c:\Users\I065659\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\wrappers\sklearn_wrapper.py:8
#       6 from keras.src.models.cloning import clone_model
#       7 from keras.src.models.model import Model
# ----> 8 from keras.src.wrappers.fixes import _routing_enabled
#       9 from keras.src.wrappers.fixes import _validate_data
#      10 from keras.src.wrappers.fixes import type_of_target
#
# File c:\Users\I065659\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\wrappers\fixes.py:2
#       1 try:
# ----> 2     import sklearn
#       3 except ImportError:
#       4     sklearn = None
#
# File c:\Users\I065659\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\__init__.py:73
#      62 # `_distributor_init` allows distributors to run custom init code.
#      63 # For instance, for the Windows wheel, this is used to pre-load the
#      64 # vcomp shared library runtime for OpenMP embedded in the sklearn/.libs
#    (...)
#      67 # later is linked to the OpenMP runtime to make it possible to introspect
#      68 # it and importing it first would fail if the OpenMP dll cannot be found.
#      69 from . import (  # noqa: F401 E402
#      70     __check_build,
#      71     _distributor_init,
#      72 )
# ---> 73 from .base import clone  # noqa: E402
#      74 from .utils._show_versions import show_versions  # noqa: E402
#      76 _submodules = [
#      77     "calibration",
#      78     "cluster",
#    (...)
#     114     "compose",
#     115 ]
#
# File c:\Users\I065659\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:19
#      17 from ._config import config_context, get_config
#      18 from .exceptions import InconsistentVersionWarning
# ---> 19 from .utils._metadata_requests import _MetadataRequester, _routing_enabled
#      20 from .utils._missing import is_scalar_nan
#      21 from .utils._param_validation import validate_parameter_constraints
#
# File c:\Users\I065659\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\__init__.py:9
#       7 from . import metadata_routing
#       8 from ._bunch import Bunch
# ----> 9 from ._chunking import gen_batches, gen_even_slices
#      11 # Make _safe_indexing importable from here for backward compat as this particular
#      12 # helper is considered semi-private and typically very useful for third-party
#      13 # libraries that want to comply with scikit-learn's estimator API. In particular,
#      14 # _safe_indexing was included in our public API documentation despite the leading
#      15 # `_` in its name.
#      16 from ._indexing import (
#      17     _safe_indexing,  # noqa: F401
#      18     resample,
#      19     shuffle,
#      20 )
#
# File c:\Users\I065659\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\_chunking.py:11
#       8 import numpy as np
#      10 from .._config import get_config
# ---> 11 from ._param_validation import Interval, validate_params
#      14 def chunk_generator(gen, chunksize):
#      15     """Chunk generator, ``gen`` into lists of length ``chunksize``. The last
#      16     chunk may have a length less than ``chunksize``."""
#
# File c:\Users\I065659\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\_param_validation.py:17
#      14 from scipy.sparse import csr_matrix, issparse
#      16 from .._config import config_context, get_config
# ---> 17 from .validation import _is_arraylike_not_scalar
#      20 class InvalidParameterError(ValueError, TypeError):
#      21     """Custom exception to be raised when the parameter of a class/method/function
#      22     does not have a valid type or value.
#      23     """
#
# File c:\Users\I065659\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:21
#      19 from .. import get_config as _get_config
#      20 from ..exceptions import DataConversionWarning, NotFittedError, PositiveSpectrumWarning
# ---> 21 from ..utils._array_api import _asarray_with_order, _is_numpy_namespace, get_namespace
#      22 from ..utils.deprecation import _deprecate_force_all_finite
#      23 from ..utils.fixes import ComplexWarning, _preserve_dia_indices_dtype
#
# File c:\Users\I065659\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\_array_api.py:20
#      18 from ..externals import array_api_extra as xpx
#      19 from ..externals.array_api_compat import numpy as np_compat
# ---> 20 from .fixes import parse_version
#      22 # TODO: complete __all__
#      23 __all__ = ["xpx"]  # we import xpx here just to re-export it, need this to appease ruff
#
# File c:\Users\I065659\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\fixes.py:16
#      14 import scipy
#      15 import scipy.sparse.linalg
# ---> 16 import scipy.stats
#      17 from scipy import optimize
#      19 try:
#
# File c:\Users\I065659\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\stats\__init__.py:624
#       1 """
#       2 .. _statsrefmanual:
#       3
#    (...)
#     619
#     620 """  # noqa: E501
#     622 from ._warnings_errors import (ConstantInputWarning, NearConstantInputWarning,
#     623                                DegenerateDataWarning, FitError)
# --> 624 from ._stats_py import *
#     625 from ._variation import variation
#     626 from .distributions import *
#
# File c:\Users\I065659\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\stats\_stats_py.py:52
#      49 # Import unused here but needs to stay until end of deprecation periode
#      50 # See https://github.com/scipy/scipy/issues/15765#issuecomment-1875564522
#      51 from scipy import linalg  # noqa: F401
# ---> 52 from . import distributions
#      53 from . import _mstats_basic as mstats_basic
#      55 from ._stats_mstats_common import _find_repeats, theilslopes, siegelslopes
#
# File c:\Users\I065659\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\stats\distributions.py:10
#       1 #
#       2 # Author:  Travis Oliphant  2002-2011 with contributions from
#       3 #          SciPy Developers 2004-2011
#    (...)
#       6 #       instead of `git blame -Lxxx,+x`.
#       7 #
#       8 from ._distn_infrastructure import (rv_discrete, rv_continuous, rv_frozen)  # noqa: F401
# ---> 10 from . import _continuous_distns
#      11 from . import _discrete_distns
#      13 from ._continuous_distns import *  # noqa: F403
#
# File c:\Users\I065659\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\stats\_continuous_distns.py:12
#      10 import numpy as np
#      11 from numpy.polynomial import Polynomial
# ---> 12 from scipy.interpolate import BSpline
#      13 from scipy._lib.doccer import (extend_notes_in_docstring,
#      14                                replace_notes_in_docstring,
#      15                                inherit_docstring_from)
#      16 from scipy._lib._ccallback import LowLevelCallable
#
# File c:\Users\I065659\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\interpolate\__init__.py:179
#       1 """
#       2 ========================================
#       3 Interpolation (:mod:`scipy.interpolate`)
#    (...)
#     177 (should not be used in new code).
#     178 """
# --> 179 from ._interpolate import *
#     180 from ._fitpack_py import *
#     182 # New interface to fitpack library:
#
# File c:\Users\I065659\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\interpolate\_interpolate.py:12
#       9 from scipy._lib._util import copy_if_needed
#      10 from scipy.special import comb
# ---> 12 from . import _fitpack_py
#      13 from ._polyint import _Interpolator1D
#      14 from . import _ppoly
#
# File c:\Users\I065659\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\interpolate\_fitpack_py.py:10
#       8 from ._fitpack_impl import bisplrep, bisplev, dblint  # noqa: F401
#       9 from . import _fitpack_impl as _impl
# ---> 10 from ._bsplines import BSpline
#      13 def splprep(x, w=None, u=None, ub=None, ue=None, k=3, task=0, s=None, t=None,
#      14             full_output=0, nest=None, per=0, quiet=1):
#      15     """
#      16     Find the B-spline representation of an N-D curve.
#      17
#    (...)
#     156
#     157     """
#
# File c:\Users\I065659\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\interpolate\_bsplines.py:10
#       6 from scipy.linalg import (get_lapack_funcs, LinAlgError,
#       7                           cholesky_banded, cho_solve_banded,
#       8                           solve, solve_banded)
#       9 from scipy.optimize import minimize_scalar
# ---> 10 from . import _dierckx
#      11 from . import _fitpack_impl
#      12 from scipy.sparse import csr_array
#
# KeyboardInterrupt:

# %% [markdown]
# Load the dataset.

# %%
# Load and unzip the dataset

# %% [markdown]
# ## **2. Data Preparation** <font color=red> [25 marks] </font><br>

# %% [markdown]
# ### **2.1 Load and Preprocess Images** <font color=red> [8 marks] </font><br>

# %% [markdown]
# Let us create a function to load the images first. We can then directly use this function while loading images of the different categories to load and crop them in a single step.

# %% [markdown]
# #### **2.1.1** <font color=red> [3 marks] </font><br>
# Create a function to load the images.

# %%
# Create a function to load the raw images

# %% [markdown]
# #### **2.1.2** <font color=red> [5 marks] </font><br>
# Load images and labels.

# %% [markdown]
# Load the images from the dataset directory. Labels of images are present in the subdirectories.
#
# Verify if the images and labels are loaded correctly.

# %%
# Get the images and their labels

# %% [markdown]
# Perform any operations, if needed, on the images and labels to get them into the desired format.

# %% [markdown]
# ### **2.2 Data Visualisation** <font color=red> [9 marks] </font><br>

# %% [markdown]
# #### **2.2.1** <font color=red> [3 marks] </font><br>
# Create a bar plot to display the class distribution

# %%
# Visualise Data Distribution

# %% [markdown]
# #### **2.2.2** <font color=red> [3 marks] </font><br>
# Visualise some sample images

# %%
# Visualise Sample Images (across different labels)

# %% [markdown]
# #### **2.2.3** <font color=red> [3 marks] </font><br>
# Based on the smallest and largest image dimensions, resize the images.

# %%
# Find the smallest and largest image dimensions from the data set

# %%
# Resize the image dimensions

# %% [markdown]
# ### **2.3 Encoding the classes** <font color=red> [3 marks] </font><br>

# %% [markdown]
# There are seven classes present in the data.
#
# We have extracted the images and their labels, and visualised their distribution. Now, we need to perform encoding on the labels. Encode the labels suitably.

# %% [markdown]
# ####**2.3.1** <font color=red> [3 marks] </font><br>
# Encode the target class labels.

# %%
# Encode the labels suitably

# %% [markdown]
# ### **2.4 Data Splitting** <font color=red> [5 marks] </font><br>

# %% [markdown]
# #### **2.4.1** <font color=red> [5 marks] </font><br>
# Split the dataset into training and validation sets

# %%
# Assign specified parts of the dataset to train and validation sets

# %% [markdown]
# ## **3. Model Building and Evaluation** <font color=red> [20 marks] </font><br>

# %% [markdown]
# ### **3.1 Model building and training** <font color=red> [15 marks] </font><br>

# %% [markdown]
# #### **3.1.1** <font color=red> [10 marks] </font><br>
# Build and compile the model. Use 3 convolutional layers. Add suitable normalisation, dropout, and fully connected layers to the model.

# %% [markdown]
# Test out different configurations and report the results in conclusions.

# %%
# Build and compile the model

# %% [markdown]
# #### **3.1.2** <font color=red> [5 marks] </font><br>
# Train the model.

# %% [markdown]
# Use appropriate metrics and callbacks as needed.

# %%
# Training

# %% [markdown]
# ### **3.2 Model Testing and Evaluation** <font color=red> [5 marks] </font><br>

# %% [markdown]
# #### **3.2.1** <font color=red> [5 marks] </font><br>
# Evaluate the model on test dataset. Derive appropriate metrics.

# %%
# Evaluate on the test set; display suitable metrics

# %% [markdown]
# ## **4. Data Augmentation** <font color=red> [optional] </font><br>

# %% [markdown]
# #### **4.1 Create a Data Augmentation Pipeline**

# %% [markdown]
# ##### **4.1.1**
# Define augmentation steps for the datasets.

# %%
# Define augmentation steps to augment images

# %% [markdown]
# Augment and resample the images.
# In case of class imbalance, you can also perform adequate undersampling on the majority class and augment those images to ensure consistency in the input datasets for both classes.

# %% [markdown]
# Augment the images.

# %%
# Create a function to augment the images

# %%
# Create the augmented training dataset

# %% [markdown]
# ##### **4.1.2**
#
# Train the model on the new augmented dataset.

# %%
# Train the model using augmented images

# %% [markdown]
# ## **5. Conclusions** <font color = red> [5 marks]</font>

# %% [markdown]
# #### **5.1 Conclude with outcomes and insights gained** <font color =red> [5 marks] </font>

# %% [markdown]
# * Report your findings about the data
# * Report model training results
